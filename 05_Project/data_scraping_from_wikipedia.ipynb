# %%
# !pip install pywikibot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 690 kB 6.5 MB/s
# ...

# %%
# !git clone https://github.com/wikimedia/pywikibot.git --depth 1
# Out:
# Cloning into 'pywikibot'...
# remote: Enumerating objects: 591, done.
# remote: Counting objects: 100% (591/591), done.
# remote: Compressing objects: 100% (478/478), done.
# remote: Total 591 (delta 112), reused 296 (delta 99), pack-reused 0
# Receiving objects: 100% (591/591), 1.64 MiB | 11.66 MiB/s, done.
# Resolving deltas: 100% (112/112), done.

# %%
# !pip install "wikitextparser>=0.47.5"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 65 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 772 kB 14.4 MB/s
# ...
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.6.2
#     Uninstalling regex-2022.6.2:
#       Successfully uninstalled regex-2022.6.2
# ...

# %%
# !python3 -m pip install -U setuptools
# !python3 -m pip install -e pywikibot/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.2 MB 7.0 MB/s
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/pywikibot
# ...
#   Attempting uninstall: pywikibot
#     Found existing installation: pywikibot 7.7.2
#     Uninstalling pywikibot-7.7.2:
#       Successfully uninstalled pywikibot-7.7.2
#   Running setup.py develop for pywikibot
# ...

# %%
cd pywikibot/
# Out:
# /content/pywikibot

# %%
# !python3 pwb.py generate_user_files.py
# Out:
# You can abort at any time by pressing ctrl-c
#
# Your default user directory is "/content/pywikibot"
#  1: commons
#  2: foundation
#  3: i18n
#  4: incubator
#  5: lingualibre
#  6: mediawiki
#  7: meta
#  8: osm
#  9: outreach
# 10: species
# 11: vikidia
# 12: wikibooks
# 13: wikidata
# 14: wikihow
# 15: wikimania
# 16: wikimediachapter
# 17: wikinews
# 18: wikipedia
# 19: wikiquote
# 20: wikisource
# 21: wikispore
# 22: wikitech
# 23: wikiversity
# 24: wikivoyage
# 25: wiktionary
# 26: wowwiki
# Select family of sites we are working on, just enter the number or name (default: wikipedia): 25
# This is the list of known site codes:
# ...

# %%
# !python pwb.py login.py
# Out:
# WARNING: No user is logged in on site wiktionary:en
# Password for user Amritanshusingh11 on wiktionary:en (no characters will be shown):
# Logging in to wiktionary:en as Amritanshusingh11
# Logged in on wiktionary:en as Amritanshusingh11.
#
# Execution time: 10 seconds

# %%
import pywikibot
from pywikibot import pagegenerators

# %%
site = pywikibot.Site()
cat = pywikibot.Category(site,'Category:Male given names by language')
gen = pagegenerators.CategorizedPageGenerator(cat, recurse=True)
#gen = pagegenerators.CategorizedPageGenerator(cat)

# %%
text_list = []
for idx,page in enumerate(gen):
    text = page.text
    text_list.append(text)
    print(idx)
    print(text)
# Out:
# Streaming output truncated to the last 5000 lines.
# ===Pronunciation===
# {{vi-IPA}}
# * {{hmp|vi|tây|tay}}
#
# ===Proper noun===
# {{vi-propn}}
#
# # {{given name|vi|male|from=Chinese}}
# # {{lb|vi|combining form}} [[Hispano-]]; [[Spain]]
#
# ===Adjective===
# {{vi-adj}}
#
# # {{alternative case form of|vi|tây||[[Western]]; [[European]] and [[American]]}}
#
# {{C|vi|Spain}}
# 24307
# {{also|thách|thạch}}
# ==Vietnamese==
#
# ===Etymology===
# {{vi-etym-sino|石}}. From the [[Chinese]] surname [[Shi]] (compare the [[Korean]] surname [[Seok]]) or from the [[Khmer]] surname [[Sok]].
#
# ===Pronunciation===
# {{vi-IPA}}
# * {{hmp|vi|thạch}}
#
# ===Proper noun===
# {{vi-propn|head=[[thạch|Thạch]]}}
#
# # {{surname|vi|from=Chinese}}
# # {{surname|vi|from=Khmer}}
# # {{given name|vi|male|from=Chinese}}
# 24308
# {{also|thai|Thai|thaï|Thaï|þai|Thai.}}
# ==Vietnamese==
#
# ===Pronunciation===
# {{vi-IPA}}
# * {{hmp|vi|thái}}
#
# ===Etymology 1===
# {{vi-etym-sino|蔡}}.
#
# ====Proper noun====
# ...

# %%
wiki_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## the code and concept for this notebook has been referenced from:
# 1. https://www.mediawiki.org/wiki/Manual:Pywikibot/Installation#Configure_Pywikibot
# 2. https://stackoverflow.com/questions/71012050/get-all-names-from-wikipedia-site/71456019#71456019
